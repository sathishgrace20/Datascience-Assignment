# %%
import pandas as pd

# %%
dataset=pd.read_csv("Placement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %% [markdown]
# Q1)Replace the NaN values with correct value. And justify why you have
#  chosen the same?

# %%
dataset.fillna(0,inplace=True)

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %% [markdown]
# Ans:The NaN values of salary is replaced by "0", as the salary is depending upon the placement, we have the options of replacing mean, median, mode,
# and etc..., if we replaced the Nan apart from Zero, then the entire dataset will not be good for analyse.

# %% [markdown]
# Q2)How many of them are not placed?

# %%
dataset["status"]=="Not Placed"
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 210    False
# 211    False
# 212    False
# 213    False
# 214     True
# Name: status, Length: 215, dtype: bool

# %%
dataset[dataset["status"]=="Not Placed"]
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 3        4      M   56.0  Central   52.0  Central   Science     52.00
# 5        6      M   55.0   Others   49.8   Others   Science     67.25
# 6        7      F   46.0   Others   49.2   Others  Commerce     79.00
# 9       10      M   58.0  Central   70.0  Central  Commerce     61.00
# 12      13      F   47.0  Central   55.0   Others   Science     65.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 198    199      F   67.0  Central   70.0  Central  Commerce     65.00
# 201    202      M   54.2  Central   63.0   Others   Science     58.00
# 206    207      M   41.0  Central   42.0  Central   Science     60.00
# 208    209      F   43.0  Central   60.0   Others   Science     65.00
# 214    215      M   62.0  Central   58.0   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status  salary
# ...

# %%
len(dataset[dataset["status"]=="Not Placed"])
# Out:
# 67

# %% [markdown]
# Ans: Totally 67 candidates are not placed.

# %% [markdown]
# Q:3)Find the reason for non placement from the dataset?

# %%
not_placed=dataset[dataset['status']=="Not Placed"]

# %%
not_placed
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 3        4      M   56.0  Central   52.0  Central   Science     52.00
# 5        6      M   55.0   Others   49.8   Others   Science     67.25
# 6        7      F   46.0   Others   49.2   Others  Commerce     79.00
# 9       10      M   58.0  Central   70.0  Central  Commerce     61.00
# 12      13      F   47.0  Central   55.0   Others   Science     65.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 198    199      F   67.0  Central   70.0  Central  Commerce     65.00
# 201    202      M   54.2  Central   63.0   Others   Science     58.00
# 206    207      M   41.0  Central   42.0  Central   Science     60.00
# 208    209      F   43.0  Central   60.0   Others   Science     65.00
# 214    215      M   62.0  Central   58.0   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status  salary
# ...

# %%
not_placed[not_placed['workex']=="Yes"]['status'].count()
# Out:
# np.int64(10)

# %%
not_placed[not_placed['workex']=="No"]['status'].count()
# Out:
# np.int64(57)

# %%
quan=[]
for columnName in dataset.columns:
    if dataset[columnName].dtype!='O':
        quan.append(columnName)

# %%
quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
dataset[quan].corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.002543
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.002543  0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %% [markdown]
# Ans:Part1: Workex --> Out of 67 of not placed candidates, 57 are no work experience, so we can conclude workex plays one of the non placement.
# Part2: ssc_p is positve corrollate with salary but less proportionate. it means 10th passmark doesnot plays major role than any other pass marks for the placement.
# so that we can conclude the ssc_p is not playing good factor on pladement.

# %% [markdown]
# Q4)What kind of relation between salary and mba_p?

# %%
dataset[quan].corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.002543
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.002543  0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %% [markdown]
# Answer:The relationship between salary and mba shows --0.139823, it is postive relation with minimul increase, it is neglegible
# amount of increase in salary based on the pass mark of mba.

# %% [markdown]
# Q5)Which specialization is getting minimum salary?

# %%
dataset["specialisation"].unique()
# Out:
# array(['Mkt&HR', 'Mkt&Fin'], dtype=object)

# %%
dataset[dataset["salary"]>0].groupby("specialisation").min()
# Out:
#                 sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b hsc_s  degree_p  \
# specialisation
# Mkt&Fin             2      F  49.00  Central  50.83  Central  Arts      56.0
# Mkt&HR              1      F  55.68  Central  53.00  Central  Arts      56.0
#
#                  degree_t workex  etest_p  mba_p  status    salary
# specialisation
# Mkt&Fin         Comm&Mgmt     No    50.48  52.81  Placed  200000.0
# Mkt&HR          Comm&Mgmt     No    50.00  52.38  Placed  200000.0

# %% [markdown]
# Answer:Both the specialiation getting the minimum salary of 200000

# %% [markdown]
# Q6)How many of them getting above 500000 salary?

# %%
dataset[dataset["salary"]>500000]['salary'].count()
# Out:
# np.int64(3)

# %% [markdown]
# Answer: Totally 3 candidates are getting above 500000 salary

# %% [markdown]
# Q7)Test the Analysis of Variance between etest_p and mba_p at signifance level 5%.(Make decision using Hypothesis Testing)

# %%
from scipy import stats
stats.f_oneway(dataset['etest_p'],dataset['mba_p'])
# Out:
# F_onewayResult(statistic=np.float64(98.64487057324706), pvalue=np.float64(4.672547689133573e-21))

# %% [markdown]
# Answer: Null Hypothesis--> There is no significant difference between the etest_p and mba_p
# Alternate Hypothesis--> There is significant difference between etest_p and mba_p
# If the pvalue<0.05, then we can reject the null hypothesis.
# Here pvalue is 0.000000000000000000004672547689133573, it is less than 0.05, so we can rejet the null hypothesis.
# We will accept the altenate hypothesis--> There is significant difference rtest_p and mba_p

# %% [markdown]
# Q8:Test the similarity between the degree_t(Sci&Tech) and specialisation(Mkt&HR) with respect to salary at significance level of 5%.(Make decision using Hypothesis Testing)

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

d = dataset[(dataset['degree_t'] == 'Sci&Tech') | (dataset['specialisation'] == 'Mkt&HR')]

model = ols("salary ~ C(degree_t) + C(specialisation) + C(degree_t):C(specialisation)", data=d).fit()

anova_table = sm.stats.anova_lm(model, typ=2)
# Out:
# C:\Users\sathi\anaconda3\envs\aiml1\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 2, but rank is 1
#   warnings.warn('covariance of constraints does not have full '

# %%
anova_table
# Out:
#                                      sum_sq     df          F        PR(>F)
# C(degree_t)                    1.681733e+12    2.0  39.016162  6.491854e-09
# C(specialisation)              5.553910e+09    1.0   0.257701  6.126279e-01
# C(degree_t):C(specialisation)  2.174367e+11    2.0   5.044527  7.865853e-03
# Residual                       2.607761e+12  121.0        NaN           NaN

# %% [markdown]
# pvalue is 0.007865853
# #Null Hypothesis --> There is no similarity between the mk&hr and sci&tech
# #Alternate hypothesis -->There is similarity between the mk&hr and sci&tech
# #Reject null hypo if the pvalues is <=0.05
# #0.00786
# #We can reject the null hypo, we accept alternate hypo
# There is similarity between the mk&hr and sci&tech

# %% [markdown]
# Q9:Convert the normal distribution to standard normal distribution for salary column

# %%
dataset=pd.read_csv("Placement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
def stdNBgraph(dataset):
    import seaborn as sns
    mean=dataset.mean()
    std=dataset.std()
    values=[i for i in dataset]
    z_score=[((j-mean)/std) for j in values]
    sns.histplot(z_score,kde=True)
    sum(z_score)/len(z_score)

# %%
stdNBgraph(dataset['salary'])

# %% [markdown]
# Answer: Standard normal distribution--> mean =0 and std deviation = 1,
# The value mean(average) is 0 and the value increased by 1 in the right, value decreased by 1 in the left.

# %% [markdown]
# Q10-What is the probability Density Function of the salary range from 700000 to 900000?

# %%
import seaborn as sns
sns.histplot(dataset['salary'],kde=True)
# Out:
# <Axes: xlabel='salary', ylabel='Count'>

# %%
def get_pdf_probability(dataset,startrange,endrange):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax=sns.distplot(dataset,kde=True, kde_kws={'color':'blue'},color='Green')
    pyplot.axvline(startrange,color='Red')
    pyplot.axvline(endrange,color='Red')
    #Generate sample
    sample = dataset
    #Calculate parameters
    sample_mean=sample.mean()
    sample_std=sample.std()
    print('Mean=%.3f, standard Deviation=%.3f' %(sample_mean, sample_std))
    #define the distribution
    dist= norm(sample_mean,sample_std)
    #Sample probability for range of outcomes
    values=[value for value in range(startrange,endrange)]
    probabilities=[dist.pdf(value) for value in values]
    prob=sum(probabilities)
    print("The area between range({},{}:{}".format(startrange,endrange,sum(probabilities)))
    return prob

# %%
get_pdf_probability(dataset['salary'],700000,900000)
# Out:
# C:\Users\sathi\AppData\Local\Temp\ipykernel_6196\1545151119.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(dataset,kde=True, kde_kws={'color':'blue'},color='Green')
# Mean=288655.405, standard Deviation=93457.452
# The area between range(700000,900000:5.377578376230696e-06
# np.float64(5.377578376230696e-06)

# %% [markdown]
# Percentage of density occur = 0.000005377578376230696, the density is neglible values are there.

# %%
get_pdf_probability(dataset['salary'],200000,400000)
# Out:
# C:\Users\sathi\AppData\Local\Temp\ipykernel_6196\1545151119.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(dataset,kde=True, kde_kws={'color':'blue'},color='Green')
# Mean=288655.405, standard Deviation=93457.452
# The area between range(200000,400000:0.7118432149872335
# np.float64(0.7118432149872335)

# %% [markdown]
# PDF falls more values betweeen 200000 and 400000

# %% [markdown]
# #Q.11-Test the similarity between the degree_t(Sci&Tech)with respect to etest_p and mba_p at significance level of 5%.(Make decision using Hypothesis Testing)

# %%
from scipy.stats import ttest_ind
scitest=dataset[dataset['degree_t']=='Sci&Tech']['mba_p']
scitest1=dataset[dataset['degree_t']=='Sci&Tech']['etest_p']
ttest_ind(scitest,scitest1)
# Out:
# TtestResult(statistic=np.float64(-4.532000225151251), pvalue=np.float64(1.4289217003775636e-05), df=np.float64(116.0))

# %% [markdown]
# #pvalue--> 0.000014289217003775636
# Null Hypothesis--> There is no similarity between mba,etest for degree_
# Alter Hypothesis--> There is similarity between these..
# #Rejection for Nul hypothesis --> pvalue less than or eaual to 0.05. pvalue is 0.000014289217003775636
# We can reject the null hypothesis, and approve the alternate hypothesis--> There is similarity between mba,etest and deggree

# %% [markdown]
# Q.12)Which parameter is highly correlated with salary?

# %%
dataset[quan].corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.063764
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.035330
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.076819
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364 -0.019272
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.178307
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.175013
# salary    0.063764  0.035330  0.076819 -0.019272  0.178307  0.175013  1.000000

# %% [markdown]
# Answer: salary is highly correlated with ssc_p, it is positive and more than 50%, not highly correllated but among other parameter
# ssc_p is the only parameter highly correlated.

# %% [markdown]
# #Q13)plot any useful graph and explain it.

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
get_pdf_probability(dataset['mba_p'],50,70)
# Out:
# Mean=62.278, standard Deviation=5.833
# The area between range(50,70:0.8782800051184135
# C:\Users\sathi\AppData\Local\Temp\ipykernel_6196\1545151119.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(dataset,kde=True, kde_kws={'color':'blue'},color='Green')
# np.float64(0.8782800051184135)

# %% [markdown]
# Answer: The graph shows the mba pass mark falls between 50 and 70, 87% of the students students scored the mark between 50 and 70
